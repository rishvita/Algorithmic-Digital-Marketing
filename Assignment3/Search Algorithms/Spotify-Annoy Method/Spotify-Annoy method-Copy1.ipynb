# %%
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial

# %%
#################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

# %%
#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)

# %%
get_image_feature_vectors()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Mon Nov  2 22:50:44 2020
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Mon Nov  2 22:50:46 2020
# --- 0.03 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Mon Nov  2 22:50:46 2020
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\0_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\0_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\101_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\101_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\11_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\11_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\12_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\12_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\13_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\13_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\13_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\13_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\13_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\13_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\13_3.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\13_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\15_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\15_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\16_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\16_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\17_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\17_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\18_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\18_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\19_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\19_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\19_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\19_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\1_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\1_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\20_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\20_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\22_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\22_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\25_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\25_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\25_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\25_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\25_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\25_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :21
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\25_3.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\25_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :22
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\26_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\26_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :23
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\26_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\26_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :24
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\26_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\26_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :25
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\26_3.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\26_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :26
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\28_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\28_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :27
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\2_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\2_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :28
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\30_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\30_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :29
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\31_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\31_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :30
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\33_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\33_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :31
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\33_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\33_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :32
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\34_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\34_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :33
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\35_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\35_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :34
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\36_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\36_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :35
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\37_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\37_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :36
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\38_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\38_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :37
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\39_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\39_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :38
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\39_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\39_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :39
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\3_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\3_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :40
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\40_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\40_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :41
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\41_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\41_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :42
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\42_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\42_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :43
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\42_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\42_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :44
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\43_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\43_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :45
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\43_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\43_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :46
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\43_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\43_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :47
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\44_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\44_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :48
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\45_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\45_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :49
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\46_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\46_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :50
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\47_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\47_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :51
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\48_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\48_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :52
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\4_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\4_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :53
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\50_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\50_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :54
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\51_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\51_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :55
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\52_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\52_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :56
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\53_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\53_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :57
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\54_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\54_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :58
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\55_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\55_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :59
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\56_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\56_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :60
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\57_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\57_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :61
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\57_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\57_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :62
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\57_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\57_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :63
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\58_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\58_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :64
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\59_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\59_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :65
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\5_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\5_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :66
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\60_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\60_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :67
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\61_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\61_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :68
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\62_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\62_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :69
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\62_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\62_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :70
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\63_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\63_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :71
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\64_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\64_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :72
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\64_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\64_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :73
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\64_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\64_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :74
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\66_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\66_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :75
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\69_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\69_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :76
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\6_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\6_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :77
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\70_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\70_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :78
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\71_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\71_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :79
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\72_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\72_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :80
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\73_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\73_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :81
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\73_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\73_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :82
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\73_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\73_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :83
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\73_3.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\73_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :84
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\74_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\74_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :85
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\75_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\75_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :86
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\76_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\76_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :87
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\76_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\76_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :88
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\77_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\77_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :89
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\79_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\79_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :90
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\7_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\7_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :91
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\80_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\80_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :92
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\81_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\81_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :93
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\83_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\83_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :94
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\84_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\84_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :95
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\87_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\87_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :96
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\88_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\88_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :97
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\89_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\89_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :98
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\8_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\8_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :99
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\90_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\90_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :100
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\91_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\91_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :101
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\92_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\92_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :102
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\95_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\95_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :103
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\97_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\97_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :104
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\97_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\97_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :105
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\98_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\98_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :106
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\98_1.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\98_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :107
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\98_2.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\98_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :108
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\98_3.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\98_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :109
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\99_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\99_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :110
# Image in process is             :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/images\9_0.jpg
# Image feature vector saved to   :C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features\9_0.npz
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors - Completed at Mon Nov  2 22:50:53 2020
# --- 0.15 minutes passed ---------
# --- 110 images processed ---------

# %%
#################################################
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched 
# So it is used to find product id based on the product image name
#################################################
def match_id(filename):
  with open('C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_test.json') as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['ImageName']:
            print(line)
            return line['ProductId']
            break

# %%
#################################################
# This function; 
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():
    
    start_time = time.time()
  
    print("---------------------------------")
    print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
    print("---------------------------------")

    # Defining data structures as empty dict
    file_index_to_file_name = {}
    file_index_to_file_vector = {}
    file_index_to_product_id = {}

    # Configuring annoy parameters
    dims = 1792
    n_nearest_neighbors = 20
    trees = 10000

    # Reads all file names which stores feature vectors 
    allfiles = glob.glob('C:/Users/rishv/OneDrive/Northeastern/SEM3/Algorithmic Digital Marketing/Assignments/Assignment3/Dataset/image_features/*.npz')

    t = AnnoyIndex(dims, metric='angular')
    

    for file_index, i in enumerate(allfiles):
        # Reads feature vectors and assigns them into the file_vector 
        file_vector = np.loadtxt(i)
        
        # Assigns file_name, feature_vectors and corresponding product_id
        file_name = os.path.basename(i).split('.')[0]
        file_index_to_file_name[file_index] = file_name # image name
        file_index_to_file_vector[file_index] = file_vector # the npz vector
        file_index_to_product_id[file_index] = match_id(file_name) # product_id in the json for that image

        # Adds image feature vectors into annoy index   
        t.add_item(file_index, file_vector)

        print("---------------------------------")
        print("Annoy index     : %s" %file_index) # index of the image
        print("Image file name : %s" %file_name) # image name
        print("Product id      : %s" %file_index_to_product_id[file_index]) # product_id
        print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
        
    # Builds annoy index
    t.build(trees)

    print ("Step.1 - ANNOY index generation - Finished")
    print ("Step.2 - Similarity score calculation - Started ") 

    named_nearest_neighbors = []

    # Loops through all indexed items
    for i in file_index_to_file_name.keys():
        # i is the index of the image
        # Assigns master file_name, image feature vectors and product id values
        master_file_name = file_index_to_file_name[i] # contains image name
        master_vector = file_index_to_file_vector[i] # contains npz vector
        master_product_id = file_index_to_product_id[i] # contains product_id

        # Calculates the nearest neighbors of the master item
        nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

        # Loops through the nearest neighbors of the master item
        for j in nearest_neighbors:
            
            print(j)

            # Assigns file_name, image feature vectors and product id values of the similar item
            neighbor_file_name = file_index_to_file_name[j] 
            neighbor_file_vector = file_index_to_file_vector[j]
            neighbor_product_id = file_index_to_product_id[j]

            # Calculates the similarity score of the similar item
            similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
            rounded_similarity = int((similarity * 10000)) / 10000.0

            # Appends master product id with the similarity score 
            # and the product id of the similar items
            #named_nearest_neighbors.append('{"index" : {"_index": "series"}}')
            named_nearest_neighbors.append({
                'similarity': rounded_similarity,
                'master_pi': master_product_id,
                'similar_pi': neighbor_product_id})

        print("---------------------------------") 
        print("Similarity index       : %s" %i)
        print("Master Image file name : %s" %file_index_to_file_name[i]) 
        print("Nearest Neighbors.     : %s" %nearest_neighbors) 
        print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
        

  
    print ("Step.2 - Similarity score calculation - Finished ") 

    # Writes the 'named_nearest_neighbors' to a json file
    with open('nearest_neighbors_test.json', 'w',encoding="utf-8") as out:
        json.dump(named_nearest_neighbors, out,ensure_ascii=False)
        
    #save_file = open("nearest_neighbors_test.json", 'a')
    #json_doc = json.dumps(named_nearest_neighbors, ensure_ascii=False)
    #save_file.write(json_doc.encode('utf8') + '\n')


    print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
    print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

# %%
cluster()
# Out:
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Wed Nov  4 22:20:20 2020
# ---------------------------------
# {'ImageName': '0_0', 'ProductId': 0, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 0
# Image file name : 0_0
# Product id      : 0
# --- 0.00 minutes passed ---------
# {'ImageName': '101_0', 'ProductId': 101, 'CategoryId': 1000004085}
# ---------------------------------
# Annoy index     : 1
# Image file name : 101_0
# Product id      : 101
# --- 0.00 minutes passed ---------
# {'ImageName': '11_0', 'ProductId': 11, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 2
# Image file name : 11_0
# Product id      : 11
# --- 0.00 minutes passed ---------
# {'ImageName': '12_0', 'ProductId': 12, 'CategoryId': 1000018306}
# ---------------------------------
# Annoy index     : 3
# Image file name : 12_0
# Product id      : 12
# --- 0.00 minutes passed ---------
# {'ImageName': '13_0', 'ProductId': 13, 'CategoryId': 1000010961}
# ---------------------------------
# Annoy index     : 4
# Image file name : 13_0
# Product id      : 13
# --- 0.00 minutes passed ---------
# {'ImageName': '13_1', 'ProductId': 13, 'CategoryId': 1000010961}
# ---------------------------------
# Annoy index     : 5
# Image file name : 13_1
# Product id      : 13
# --- 0.00 minutes passed ---------
# {'ImageName': '13_2', 'ProductId': 13, 'CategoryId': 1000010961}
# ---------------------------------
# Annoy index     : 6
# Image file name : 13_2
# Product id      : 13
# --- 0.00 minutes passed ---------
# {'ImageName': '13_3', 'ProductId': 13, 'CategoryId': 1000010961}
# ---------------------------------
# Annoy index     : 7
# Image file name : 13_3
# Product id      : 13
# --- 0.00 minutes passed ---------
# {'ImageName': '15_0', 'ProductId': 15, 'CategoryId': 1000015309}
# ---------------------------------
# Annoy index     : 8
# Image file name : 15_0
# Product id      : 15
# --- 0.00 minutes passed ---------
# {'ImageName': '16_0', 'ProductId': 16, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 9
# Image file name : 16_0
# Product id      : 16
# --- 0.00 minutes passed ---------
# {'ImageName': '17_0', 'ProductId': 17, 'CategoryId': 1000007361}
# ---------------------------------
# Annoy index     : 10
# Image file name : 17_0
# Product id      : 17
# --- 0.00 minutes passed ---------
# {'ImageName': '18_0', 'ProductId': 18, 'CategoryId': 1000018294}
# ---------------------------------
# Annoy index     : 11
# Image file name : 18_0
# Product id      : 18
# --- 0.00 minutes passed ---------
# {'ImageName': '19_0', 'ProductId': 19, 'CategoryId': 1000014287}
# ---------------------------------
# Annoy index     : 12
# Image file name : 19_0
# Product id      : 19
# --- 0.00 minutes passed ---------
# {'ImageName': '19_1', 'ProductId': 19, 'CategoryId': 1000014287}
# ---------------------------------
# Annoy index     : 13
# Image file name : 19_1
# Product id      : 19
# --- 0.00 minutes passed ---------
# {'ImageName': '1_0', 'ProductId': 1, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 14
# Image file name : 1_0
# Product id      : 1
# --- 0.00 minutes passed ---------
# {'ImageName': '20_0', 'ProductId': 20, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 15
# Image file name : 20_0
# Product id      : 20
# --- 0.00 minutes passed ---------
# {'ImageName': '22_0', 'ProductId': 22, 'CategoryId': 1000005910}
# ---------------------------------
# Annoy index     : 16
# Image file name : 22_0
# Product id      : 22
# --- 0.00 minutes passed ---------
# {'ImageName': '25_0', 'ProductId': 25, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 17
# Image file name : 25_0
# Product id      : 25
# --- 0.00 minutes passed ---------
# {'ImageName': '25_1', 'ProductId': 25, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 18
# Image file name : 25_1
# Product id      : 25
# --- 0.00 minutes passed ---------
# {'ImageName': '25_2', 'ProductId': 25, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 19
# Image file name : 25_2
# Product id      : 25
# --- 0.00 minutes passed ---------
# {'ImageName': '25_3', 'ProductId': 25, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 20
# Image file name : 25_3
# Product id      : 25
# --- 0.00 minutes passed ---------
# {'ImageName': '26_0', 'ProductId': 26, 'CategoryId': 1000001859}
# ---------------------------------
# Annoy index     : 21
# Image file name : 26_0
# Product id      : 26
# --- 0.00 minutes passed ---------
# {'ImageName': '26_1', 'ProductId': 26, 'CategoryId': 1000001859}
# ---------------------------------
# Annoy index     : 22
# Image file name : 26_1
# Product id      : 26
# --- 0.00 minutes passed ---------
# {'ImageName': '26_2', 'ProductId': 26, 'CategoryId': 1000001859}
# ---------------------------------
# Annoy index     : 23
# Image file name : 26_2
# Product id      : 26
# --- 0.00 minutes passed ---------
# {'ImageName': '26_3', 'ProductId': 26, 'CategoryId': 1000001859}
# ---------------------------------
# Annoy index     : 24
# Image file name : 26_3
# Product id      : 26
# --- 0.00 minutes passed ---------
# {'ImageName': '28_0', 'ProductId': 28, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 25
# Image file name : 28_0
# Product id      : 28
# --- 0.00 minutes passed ---------
# {'ImageName': '2_0', 'ProductId': 2, 'CategoryId': 1000004079}
# ---------------------------------
# Annoy index     : 26
# Image file name : 2_0
# Product id      : 2
# --- 0.00 minutes passed ---------
# {'ImageName': '30_0', 'ProductId': 30, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 27
# Image file name : 30_0
# Product id      : 30
# --- 0.00 minutes passed ---------
# {'ImageName': '31_0', 'ProductId': 31, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 28
# Image file name : 31_0
# Product id      : 31
# --- 0.00 minutes passed ---------
# {'ImageName': '33_0', 'ProductId': 33, 'CategoryId': 1000010647}
# ---------------------------------
# Annoy index     : 29
# Image file name : 33_0
# Product id      : 33
# --- 0.00 minutes passed ---------
# {'ImageName': '33_1', 'ProductId': 33, 'CategoryId': 1000010647}
# ---------------------------------
# Annoy index     : 30
# Image file name : 33_1
# Product id      : 33
# --- 0.00 minutes passed ---------
# {'ImageName': '34_0', 'ProductId': 34, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 31
# Image file name : 34_0
# Product id      : 34
# --- 0.00 minutes passed ---------
# {'ImageName': '35_0', 'ProductId': 35, 'CategoryId': 1000018290}
# ---------------------------------
# Annoy index     : 32
# Image file name : 35_0
# Product id      : 35
# --- 0.00 minutes passed ---------
# {'ImageName': '36_0', 'ProductId': 36, 'CategoryId': 1000004079}
# ---------------------------------
# Annoy index     : 33
# Image file name : 36_0
# Product id      : 36
# --- 0.00 minutes passed ---------
# {'ImageName': '37_0', 'ProductId': 37, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 34
# Image file name : 37_0
# Product id      : 37
# --- 0.00 minutes passed ---------
# {'ImageName': '38_0', 'ProductId': 38, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 35
# Image file name : 38_0
# Product id      : 38
# --- 0.00 minutes passed ---------
# {'ImageName': '39_0', 'ProductId': 39, 'CategoryId': 1000011423}
# ---------------------------------
# Annoy index     : 36
# Image file name : 39_0
# Product id      : 39
# --- 0.00 minutes passed ---------
# {'ImageName': '39_1', 'ProductId': 39, 'CategoryId': 1000011423}
# ---------------------------------
# Annoy index     : 37
# Image file name : 39_1
# Product id      : 39
# --- 0.00 minutes passed ---------
# {'ImageName': '3_0', 'ProductId': 3, 'CategoryId': 1000004141}
# ---------------------------------
# Annoy index     : 38
# Image file name : 3_0
# Product id      : 3
# --- 0.00 minutes passed ---------
# {'ImageName': '40_0', 'ProductId': 40, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 39
# Image file name : 40_0
# Product id      : 40
# --- 0.00 minutes passed ---------
# {'ImageName': '41_0', 'ProductId': 41, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 40
# Image file name : 41_0
# Product id      : 41
# --- 0.00 minutes passed ---------
# {'ImageName': '42_0', 'ProductId': 42, 'CategoryId': 1000012989}
# ---------------------------------
# Annoy index     : 41
# Image file name : 42_0
# Product id      : 42
# --- 0.00 minutes passed ---------
# {'ImageName': '42_1', 'ProductId': 42, 'CategoryId': 1000012989}
# ---------------------------------
# Annoy index     : 42
# Image file name : 42_1
# Product id      : 42
# --- 0.01 minutes passed ---------
# {'ImageName': '43_0', 'ProductId': 43, 'CategoryId': 1000004079}
# ---------------------------------
# Annoy index     : 43
# Image file name : 43_0
# Product id      : 43
# --- 0.01 minutes passed ---------
# {'ImageName': '43_1', 'ProductId': 43, 'CategoryId': 1000004079}
# ---------------------------------
# Annoy index     : 44
# Image file name : 43_1
# Product id      : 43
# --- 0.01 minutes passed ---------
# {'ImageName': '43_2', 'ProductId': 43, 'CategoryId': 1000004079}
# ---------------------------------
# Annoy index     : 45
# Image file name : 43_2
# Product id      : 43
# --- 0.01 minutes passed ---------
# {'ImageName': '44_0', 'ProductId': 44, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 46
# Image file name : 44_0
# Product id      : 44
# --- 0.01 minutes passed ---------
# {'ImageName': '45_0', 'ProductId': 45, 'CategoryId': 1000012558}
# ---------------------------------
# Annoy index     : 47
# Image file name : 45_0
# Product id      : 45
# --- 0.01 minutes passed ---------
# {'ImageName': '46_0', 'ProductId': 46, 'CategoryId': 1000010061}
# ---------------------------------
# Annoy index     : 48
# Image file name : 46_0
# Product id      : 46
# --- 0.01 minutes passed ---------
# {'ImageName': '47_0', 'ProductId': 47, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 49
# Image file name : 47_0
# Product id      : 47
# --- 0.01 minutes passed ---------
# {'ImageName': '48_0', 'ProductId': 48, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 50
# Image file name : 48_0
# Product id      : 48
# --- 0.01 minutes passed ---------
# {'ImageName': '4_0', 'ProductId': 4, 'CategoryId': 1000015539}
# ---------------------------------
# Annoy index     : 51
# Image file name : 4_0
# Product id      : 4
# --- 0.01 minutes passed ---------
# {'ImageName': '50_0', 'ProductId': 50, 'CategoryId': 1000005990}
# ---------------------------------
# Annoy index     : 52
# Image file name : 50_0
# Product id      : 50
# --- 0.01 minutes passed ---------
# {'ImageName': '51_0', 'ProductId': 51, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 53
# Image file name : 51_0
# Product id      : 51
# --- 0.01 minutes passed ---------
# {'ImageName': '52_0', 'ProductId': 52, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 54
# Image file name : 52_0
# Product id      : 52
# --- 0.01 minutes passed ---------
# {'ImageName': '53_0', 'ProductId': 53, 'CategoryId': 1000012993}
# ---------------------------------
# Annoy index     : 55
# Image file name : 53_0
# Product id      : 53
# --- 0.01 minutes passed ---------
# {'ImageName': '54_0', 'ProductId': 54, 'CategoryId': 1000014396}
# ---------------------------------
# Annoy index     : 56
# Image file name : 54_0
# Product id      : 54
# --- 0.01 minutes passed ---------
# {'ImageName': '55_0', 'ProductId': 55, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 57
# Image file name : 55_0
# Product id      : 55
# --- 0.01 minutes passed ---------
# {'ImageName': '56_0', 'ProductId': 56, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 58
# Image file name : 56_0
# Product id      : 56
# --- 0.01 minutes passed ---------
# {'ImageName': '57_0', 'ProductId': 57, 'CategoryId': 1000003787}
# ---------------------------------
# Annoy index     : 59
# Image file name : 57_0
# Product id      : 57
# --- 0.01 minutes passed ---------
# {'ImageName': '57_1', 'ProductId': 57, 'CategoryId': 1000003787}
# ---------------------------------
# Annoy index     : 60
# Image file name : 57_1
# Product id      : 57
# --- 0.01 minutes passed ---------
# {'ImageName': '57_2', 'ProductId': 57, 'CategoryId': 1000003787}
# ---------------------------------
# Annoy index     : 61
# Image file name : 57_2
# Product id      : 57
# --- 0.01 minutes passed ---------
# {'ImageName': '58_0', 'ProductId': 58, 'CategoryId': 1000010706}
# ---------------------------------
# Annoy index     : 62
# Image file name : 58_0
# Product id      : 58
# --- 0.01 minutes passed ---------
# {'ImageName': '59_0', 'ProductId': 59, 'CategoryId': 1000007138}
# ---------------------------------
# Annoy index     : 63
# Image file name : 59_0
# Product id      : 59
# --- 0.01 minutes passed ---------
# {'ImageName': '5_0', 'ProductId': 5, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 64
# Image file name : 5_0
# Product id      : 5
# --- 0.01 minutes passed ---------
# {'ImageName': '60_0', 'ProductId': 60, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 65
# Image file name : 60_0
# Product id      : 60
# --- 0.01 minutes passed ---------
# {'ImageName': '61_0', 'ProductId': 61, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 66
# Image file name : 61_0
# Product id      : 61
# --- 0.01 minutes passed ---------
# {'ImageName': '62_0', 'ProductId': 62, 'CategoryId': 1000003191}
# ---------------------------------
# Annoy index     : 67
# Image file name : 62_0
# Product id      : 62
# --- 0.01 minutes passed ---------
# {'ImageName': '62_1', 'ProductId': 62, 'CategoryId': 1000003191}
# ---------------------------------
# Annoy index     : 68
# Image file name : 62_1
# Product id      : 62
# --- 0.01 minutes passed ---------
# {'ImageName': '63_0', 'ProductId': 63, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 69
# Image file name : 63_0
# Product id      : 63
# --- 0.01 minutes passed ---------
# {'ImageName': '64_0', 'ProductId': 64, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 70
# Image file name : 64_0
# Product id      : 64
# --- 0.01 minutes passed ---------
# {'ImageName': '64_1', 'ProductId': 64, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 71
# Image file name : 64_1
# Product id      : 64
# --- 0.01 minutes passed ---------
# {'ImageName': '64_2', 'ProductId': 64, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 72
# Image file name : 64_2
# Product id      : 64
# --- 0.01 minutes passed ---------
# {'ImageName': '66_0', 'ProductId': 66, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 73
# Image file name : 66_0
# Product id      : 66
# --- 0.01 minutes passed ---------
# {'ImageName': '69_0', 'ProductId': 69, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 74
# Image file name : 69_0
# Product id      : 69
# --- 0.01 minutes passed ---------
# {'ImageName': '6_0', 'ProductId': 6, 'CategoryId': 1000005744}
# ---------------------------------
# Annoy index     : 75
# Image file name : 6_0
# Product id      : 6
# --- 0.01 minutes passed ---------
# {'ImageName': '70_0', 'ProductId': 70, 'CategoryId': 1000018294}
# ---------------------------------
# Annoy index     : 76
# Image file name : 70_0
# Product id      : 70
# --- 0.01 minutes passed ---------
# {'ImageName': '71_0', 'ProductId': 71, 'CategoryId': 1000010645}
# ---------------------------------
# Annoy index     : 77
# Image file name : 71_0
# Product id      : 71
# --- 0.01 minutes passed ---------
# {'ImageName': '72_0', 'ProductId': 72, 'CategoryId': 1000003977}
# ---------------------------------
# Annoy index     : 78
# Image file name : 72_0
# Product id      : 72
# --- 0.01 minutes passed ---------
# {'ImageName': '73_0', 'ProductId': 73, 'CategoryId': 1000005796}
# ---------------------------------
# Annoy index     : 79
# Image file name : 73_0
# Product id      : 73
# --- 0.01 minutes passed ---------
# {'ImageName': '73_1', 'ProductId': 73, 'CategoryId': 1000005796}
# ---------------------------------
# Annoy index     : 80
# Image file name : 73_1
# Product id      : 73
# --- 0.01 minutes passed ---------
# {'ImageName': '73_2', 'ProductId': 73, 'CategoryId': 1000005796}
# ---------------------------------
# Annoy index     : 81
# Image file name : 73_2
# Product id      : 73
# --- 0.01 minutes passed ---------
# {'ImageName': '73_3', 'ProductId': 73, 'CategoryId': 1000005796}
# ---------------------------------
# Annoy index     : 82
# Image file name : 73_3
# Product id      : 73
# --- 0.01 minutes passed ---------
# {'ImageName': '74_0', 'ProductId': 74, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 83
# Image file name : 74_0
# Product id      : 74
# --- 0.01 minutes passed ---------
# {'ImageName': '75_0', 'ProductId': 75, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 84
# Image file name : 75_0
# Product id      : 75
# --- 0.01 minutes passed ---------
# {'ImageName': '76_0', 'ProductId': 76, 'CategoryId': 1000013922}
# ---------------------------------
# Annoy index     : 85
# Image file name : 76_0
# Product id      : 76
# --- 0.01 minutes passed ---------
# {'ImageName': '76_1', 'ProductId': 76, 'CategoryId': 1000013922}
# ---------------------------------
# Annoy index     : 86
# Image file name : 76_1
# Product id      : 76
# --- 0.01 minutes passed ---------
# {'ImageName': '77_0', 'ProductId': 77, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 87
# Image file name : 77_0
# Product id      : 77
# --- 0.01 minutes passed ---------
# {'ImageName': '79_0', 'ProductId': 79, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 88
# Image file name : 79_0
# Product id      : 79
# --- 0.01 minutes passed ---------
# {'ImageName': '7_0', 'ProductId': 7, 'CategoryId': 1000004079}
# ---------------------------------
# Annoy index     : 89
# Image file name : 7_0
# Product id      : 7
# --- 0.01 minutes passed ---------
# {'ImageName': '80_0', 'ProductId': 80, 'CategoryId': 1000004141}
# ---------------------------------
# Annoy index     : 90
# Image file name : 80_0
# Product id      : 80
# --- 0.01 minutes passed ---------
# {'ImageName': '81_0', 'ProductId': 81, 'CategoryId': 1000010683}
# ---------------------------------
# Annoy index     : 91
# Image file name : 81_0
# Product id      : 81
# --- 0.01 minutes passed ---------
# {'ImageName': '83_0', 'ProductId': 83, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 92
# Image file name : 83_0
# Product id      : 83
# --- 0.01 minutes passed ---------
# {'ImageName': '84_0', 'ProductId': 84, 'CategoryId': 1000010641}
# ---------------------------------
# Annoy index     : 93
# Image file name : 84_0
# Product id      : 84
# --- 0.01 minutes passed ---------
# {'ImageName': '87_0', 'ProductId': 87, 'CategoryId': 1000010461}
# ---------------------------------
# Annoy index     : 94
# Image file name : 87_0
# Product id      : 87
# --- 0.01 minutes passed ---------
# {'ImageName': '88_0', 'ProductId': 88, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 95
# Image file name : 88_0
# Product id      : 88
# --- 0.01 minutes passed ---------
# {'ImageName': '89_0', 'ProductId': 89, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 96
# Image file name : 89_0
# Product id      : 89
# --- 0.01 minutes passed ---------
# {'ImageName': '8_0', 'ProductId': 8, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 97
# Image file name : 8_0
# Product id      : 8
# --- 0.01 minutes passed ---------
# {'ImageName': '90_0', 'ProductId': 90, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 98
# Image file name : 90_0
# Product id      : 90
# --- 0.01 minutes passed ---------
# {'ImageName': '91_0', 'ProductId': 91, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 99
# Image file name : 91_0
# Product id      : 91
# --- 0.01 minutes passed ---------
# {'ImageName': '92_0', 'ProductId': 92, 'CategoryId': 1000015309}
# ---------------------------------
# Annoy index     : 100
# Image file name : 92_0
# Product id      : 92
# --- 0.01 minutes passed ---------
# {'ImageName': '95_0', 'ProductId': 95, 'CategoryId': 1000010653}
# ---------------------------------
# Annoy index     : 101
# Image file name : 95_0
# Product id      : 95
# --- 0.01 minutes passed ---------
# {'ImageName': '97_0', 'ProductId': 97, 'CategoryId': 1000010683}
# ---------------------------------
# Annoy index     : 102
# Image file name : 97_0
# Product id      : 97
# --- 0.01 minutes passed ---------
# {'ImageName': '97_1', 'ProductId': 97, 'CategoryId': 1000010683}
# ---------------------------------
# Annoy index     : 103
# Image file name : 97_1
# Product id      : 97
# --- 0.01 minutes passed ---------
# {'ImageName': '98_0', 'ProductId': 98, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 104
# Image file name : 98_0
# Product id      : 98
# --- 0.01 minutes passed ---------
# {'ImageName': '98_1', 'ProductId': 98, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 105
# Image file name : 98_1
# Product id      : 98
# --- 0.01 minutes passed ---------
# {'ImageName': '98_2', 'ProductId': 98, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 106
# Image file name : 98_2
# Product id      : 98
# --- 0.01 minutes passed ---------
# {'ImageName': '98_3', 'ProductId': 98, 'CategoryId': 1000010667}
# ---------------------------------
# Annoy index     : 107
# Image file name : 98_3
# Product id      : 98
# --- 0.01 minutes passed ---------
# {'ImageName': '99_0', 'ProductId': 99, 'CategoryId': 1000014053}
# ---------------------------------
# Annoy index     : 108
# Image file name : 99_0
# Product id      : 99
# --- 0.01 minutes passed ---------
# {'ImageName': '9_0', 'ProductId': 9, 'CategoryId': 1000018290}
# ---------------------------------
# Annoy index     : 109
# Image file name : 9_0
# Product id      : 9
# --- 0.01 minutes passed ---------
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 105
# 106
# 14
# 55
# 34
# 25
# 27
# 71
# 73
# 2
# 79
# 97
# 31
# 50
# 81
# 101
# 83
# 20
# 26
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 0_0
# Nearest Neighbors.     : [0, 105, 106, 14, 55, 34, 25, 27, 71, 73, 2, 79, 97, 31, 50, 81, 101, 83, 20, 26]
# --- 0.02 minutes passed ---------
# 1
# 102
# 45
# 37
# 36
# 43
# 44
# 68
# 107
# 29
# 30
# 16
# 56
# 91
# 101
# 103
# 25
# 89
# 38
# 20
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 101_0
# Nearest Neighbors.     : [1, 102, 45, 37, 36, 43, 44, 68, 107, 29, 30, 16, 56, 91, 101, 103, 25, 89, 38, 20]
# --- 0.02 minutes passed ---------
# 2
# 83
# 73
# 27
# 66
# 88
# 40
# 104
# 31
# 49
# 53
# 0
# 106
# 105
# 46
# 55
# 51
# 97
# 50
# 82
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 11_0
# Nearest Neighbors.     : [2, 83, 73, 27, 66, 88, 40, 104, 31, 49, 53, 0, 106, 105, 46, 55, 51, 97, 50, 82]
# --- 0.02 minutes passed ---------
# 3
# 82
# 70
# 2
# 76
# 79
# 73
# 20
# 52
# 11
# 69
# 66
# 81
# 86
# 104
# 80
# 108
# 88
# 84
# 51
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 12_0
# Nearest Neighbors.     : [3, 82, 70, 2, 76, 79, 73, 20, 52, 11, 69, 66, 81, 86, 104, 80, 108, 88, 84, 51]
# --- 0.02 minutes passed ---------
# 4
# 7
# 47
# 85
# 5
# 48
# 61
# 6
# 93
# 78
# 103
# 29
# 30
# 55
# 97
# 74
# 81
# 75
# 63
# 0
# ---------------------------------
# Similarity index       : 4
# Master Image file name : 13_0
# Nearest Neighbors.     : [4, 7, 47, 85, 5, 48, 61, 6, 93, 78, 103, 29, 30, 55, 97, 74, 81, 75, 63, 0]
# --- 0.02 minutes passed ---------
# 5
# 7
# 47
# 85
# 61
# 20
# 4
# 48
# 78
# 101
# 29
# 30
# 60
# 67
# 75
# 44
# 82
# 103
# 43
# 16
# ---------------------------------
# Similarity index       : 5
# Master Image file name : 13_1
# Nearest Neighbors.     : [5, 7, 47, 85, 61, 20, 4, 48, 78, 101, 29, 30, 60, 67, 75, 44, 82, 103, 43, 16]
# --- 0.02 minutes passed ---------
# 6
# 7
# 4
# 44
# 103
# 102
# 43
# 29
# 30
# 75
# 63
# 47
# 45
# 101
# 93
# 59
# 68
# 38
# 77
# 60
# ---------------------------------
# Similarity index       : 6
# Master Image file name : 13_2
# Nearest Neighbors.     : [6, 7, 4, 44, 103, 102, 43, 29, 30, 75, 63, 47, 45, 101, 93, 59, 68, 38, 77, 60]
# --- 0.02 minutes passed ---------
# 7
# 5
# 85
# 4
# 75
# 44
# 20
# 43
# 101
# 103
# 47
# 68
# 61
# 29
# 30
# 6
# 89
# 81
# 16
# 67
# ---------------------------------
# Similarity index       : 7
# Master Image file name : 13_3
# Nearest Neighbors.     : [7, 5, 85, 4, 75, 44, 20, 43, 101, 103, 47, 68, 61, 29, 30, 6, 89, 81, 16, 67]
# --- 0.02 minutes passed ---------
# 8
# 13
# 71
# 28
# 81
# 49
# 17
# 41
# 86
# 22
# 39
# 46
# 66
# 105
# 73
# 9
# 27
# 40
# 106
# 100
# ---------------------------------
# Similarity index       : 8
# Master Image file name : 15_0
# Nearest Neighbors.     : [8, 13, 71, 28, 81, 49, 17, 41, 86, 22, 39, 46, 66, 105, 73, 9, 27, 40, 106, 100]
# --- 0.02 minutes passed ---------
# 9
# 28
# 39
# 84
# 87
# 66
# 49
# 70
# 40
# 96
# 46
# 69
# 81
# 54
# 8
# 83
# 73
# 104
# 18
# 88
# ---------------------------------
# Similarity index       : 9
# Master Image file name : 16_0
# Nearest Neighbors.     : [9, 28, 39, 84, 87, 66, 49, 70, 40, 96, 46, 69, 81, 54, 8, 83, 73, 104, 18, 88]
# --- 0.02 minutes passed ---------
# 10
# 98
# 106
# 105
# 50
# 57
# 97
# 108
# 55
# 0
# 81
# 14
# 71
# 84
# 2
# 25
# 27
# 63
# 69
# 80
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 17_0
# Nearest Neighbors.     : [10, 98, 106, 105, 50, 57, 97, 108, 55, 0, 81, 14, 71, 84, 2, 25, 27, 63, 69, 80]
# --- 0.02 minutes passed ---------
# 11
# 79
# 82
# 97
# 20
# 73
# 2
# 66
# 104
# 105
# 26
# 81
# 33
# 0
# 106
# 27
# 67
# 80
# 53
# 84
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 18_0
# Nearest Neighbors.     : [11, 79, 82, 97, 20, 73, 2, 66, 104, 105, 26, 81, 33, 0, 106, 27, 67, 80, 53, 84]
# --- 0.02 minutes passed ---------
# 12
# 80
# 26
# 29
# 30
# 68
# 101
# 83
# 53
# 89
# 46
# 16
# 33
# 37
# 19
# 91
# 38
# 22
# 13
# 74
# ---------------------------------
# Similarity index       : 12
# Master Image file name : 19_0
# Nearest Neighbors.     : [12, 80, 26, 29, 30, 68, 101, 83, 53, 89, 46, 16, 33, 37, 19, 91, 38, 22, 13, 74]
# --- 0.02 minutes passed ---------
# 13
# 8
# 49
# 105
# 17
# 39
# 81
# 66
# 41
# 106
# 71
# 89
# 19
# 27
# 40
# 0
# 28
# 25
# 97
# 22
# ---------------------------------
# Similarity index       : 13
# Master Image file name : 19_1
# Nearest Neighbors.     : [13, 8, 49, 105, 17, 39, 81, 66, 41, 106, 71, 89, 19, 27, 40, 0, 28, 25, 97, 22]
# --- 0.02 minutes passed ---------
# 14
# 105
# 0
# 106
# 57
# 58
# 27
# 97
# 71
# 98
# 108
# 81
# 73
# 8
# 13
# 25
# 34
# 2
# 78
# 82
# ---------------------------------
# Similarity index       : 14
# Master Image file name : 1_0
# Nearest Neighbors.     : [14, 105, 0, 106, 57, 58, 27, 97, 71, 98, 108, 81, 73, 8, 13, 25, 34, 2, 78, 82]
# --- 0.02 minutes passed ---------
# 15
# 98
# 95
# 50
# 25
# 31
# 19
# 17
# 0
# 106
# 27
# 22
# 55
# 34
# 105
# 92
# 97
# 49
# 58
# 40
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 20_0
# Nearest Neighbors.     : [15, 98, 95, 50, 25, 31, 19, 17, 0, 106, 27, 22, 55, 34, 105, 92, 97, 49, 58, 40]
# --- 0.02 minutes passed ---------
# 16
# 101
# 68
# 45
# 43
# 74
# 29
# 30
# 44
# 38
# 7
# 20
# 12
# 94
# 89
# 36
# 37
# 5
# 0
# 25
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 22_0
# Nearest Neighbors.     : [16, 101, 68, 45, 43, 74, 29, 30, 44, 38, 7, 20, 12, 94, 89, 36, 37, 5, 0, 25]
# --- 0.02 minutes passed ---------
# 17
# 19
# 18
# 13
# 39
# 8
# 71
# 25
# 49
# 22
# 46
# 31
# 15
# 90
# 81
# 33
# 98
# 0
# 83
# 105
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 25_0
# Nearest Neighbors.     : [17, 19, 18, 13, 39, 8, 71, 25, 49, 22, 46, 31, 15, 90, 81, 33, 98, 0, 83, 105]
# --- 0.02 minutes passed ---------
# 18
# 39
# 54
# 46
# 17
# 88
# 49
# 19
# 66
# 40
# 35
# 83
# 53
# 31
# 28
# 65
# 22
# 86
# 9
# 84
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 25_1
# Nearest Neighbors.     : [18, 39, 54, 46, 17, 88, 49, 19, 66, 40, 35, 83, 53, 31, 28, 65, 22, 86, 9, 84]
# --- 0.02 minutes passed ---------
# 19
# 17
# 18
# 25
# 39
# 13
# 15
# 55
# 22
# 49
# 54
# 74
# 31
# 98
# 8
# 46
# 100
# 40
# 71
# 83
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 25_2
# Nearest Neighbors.     : [19, 17, 18, 25, 39, 13, 15, 55, 22, 49, 54, 74, 31, 98, 8, 46, 100, 40, 71, 83]
# --- 0.02 minutes passed ---------
# 20
# 67
# 80
# 79
# 81
# 44
# 101
# 89
# 43
# 97
# 29
# 30
# 85
# 82
# 68
# 5
# 0
# 36
# 37
# 26
# ---------------------------------
# Similarity index       : 20
# Master Image file name : 25_3
# Nearest Neighbors.     : [20, 67, 80, 79, 81, 44, 101, 89, 43, 97, 29, 30, 85, 82, 68, 5, 0, 36, 37, 26]
# --- 0.02 minutes passed ---------
# 21
# 23
# 94
# 48
# 74
# 29
# 30
# 38
# 101
# 19
# 16
# 91
# 12
# 25
# 68
# 37
# 17
# 45
# 36
# 80
# ---------------------------------
# Similarity index       : 21
# Master Image file name : 26_0
# Nearest Neighbors.     : [21, 23, 94, 48, 74, 29, 30, 38, 101, 19, 16, 91, 12, 25, 68, 37, 17, 45, 36, 80]
# --- 0.02 minutes passed ---------
# 22
# 86
# 46
# 71
# 54
# 39
# 8
# 33
# 17
# 49
# 80
# 81
# 69
# 40
# 88
# 13
# 35
# 105
# 73
# 79
# ---------------------------------
# Similarity index       : 22
# Master Image file name : 26_1
# Nearest Neighbors.     : [22, 86, 46, 71, 54, 39, 8, 33, 17, 49, 80, 81, 69, 40, 88, 13, 35, 105, 73, 79]
# --- 0.02 minutes passed ---------
# 23
# 21
# 94
# 48
# 29
# 30
# 38
# 74
# 101
# 4
# 77
# 25
# 16
# 93
# 63
# 68
# 7
# 19
# 80
# 91
# ---------------------------------
# Similarity index       : 23
# Master Image file name : 26_2
# Nearest Neighbors.     : [23, 21, 94, 48, 29, 30, 38, 74, 101, 4, 77, 25, 16, 93, 63, 68, 7, 19, 80, 91]
# --- 0.02 minutes passed ---------
# 24
# 68
# 43
# 44
# 101
# 36
# 38
# 37
# 89
# 29
# 30
# 80
# 16
# 56
# 20
# 97
# 26
# 12
# 72
# 103
# ---------------------------------
# Similarity index       : 24
# Master Image file name : 26_3
# Nearest Neighbors.     : [24, 68, 43, 44, 101, 36, 38, 37, 89, 29, 30, 80, 16, 56, 20, 97, 26, 12, 72, 103]
# --- 0.02 minutes passed ---------
# 25
# 106
# 0
# 97
# 105
# 31
# 27
# 38
# 74
# 19
# 15
# 17
# 80
# 50
# 98
# 89
# 13
# 88
# 57
# 55
# ---------------------------------
# Similarity index       : 25
# Master Image file name : 28_0
# Nearest Neighbors.     : [25, 106, 0, 97, 105, 31, 27, 38, 74, 19, 15, 17, 80, 50, 98, 89, 13, 88, 57, 55]
# --- 0.02 minutes passed ---------
# 26
# 81
# 46
# 83
# 80
# 79
# 73
# 89
# 0
# 20
# 27
# 33
# 66
# 29
# 30
# 2
# 49
# 12
# 13
# 104
# ---------------------------------
# Similarity index       : 26
# Master Image file name : 2_0
# Nearest Neighbors.     : [26, 81, 46, 83, 80, 79, 73, 89, 0, 20, 27, 33, 66, 29, 30, 2, 49, 12, 13, 104]
# --- 0.02 minutes passed ---------
# 27
# 106
# 105
# 83
# 31
# 73
# 2
# 97
# 0
# 53
# 66
# 35
# 104
# 40
# 88
# 25
# 49
# 33
# 57
# 13
# ---------------------------------
# Similarity index       : 27
# Master Image file name : 30_0
# Nearest Neighbors.     : [27, 106, 105, 83, 31, 73, 2, 97, 0, 53, 66, 35, 104, 40, 88, 25, 49, 33, 57, 13]
# --- 0.02 minutes passed ---------
# 28
# 9
# 49
# 8
# 40
# 39
# 96
# 46
# 84
# 87
# 66
# 54
# 69
# 13
# 31
# 88
# 73
# 65
# 41
# 18
# ---------------------------------
# Similarity index       : 28
# Master Image file name : 31_0
# Nearest Neighbors.     : [28, 9, 49, 8, 40, 39, 96, 46, 84, 87, 66, 54, 69, 13, 31, 88, 73, 65, 41, 18]
# --- 0.02 minutes passed ---------
# 29
# 30
# 37
# 36
# 101
# 20
# 43
# 45
# 44
# 91
# 68
# 38
# 89
# 80
# 103
# 67
# 26
# 16
# 12
# 79
# ---------------------------------
# Similarity index       : 29
# Master Image file name : 33_0
# Nearest Neighbors.     : [29, 30, 37, 36, 101, 20, 43, 45, 44, 91, 68, 38, 89, 80, 103, 67, 26, 16, 12, 79]
# --- 0.02 minutes passed ---------
# 29
# 30
# 37
# 36
# 101
# 20
# 43
# 45
# 44
# 91
# 68
# 38
# 89
# 80
# 103
# 67
# 26
# 16
# 12
# 79
# ---------------------------------
# Similarity index       : 30
# Master Image file name : 33_1
# Nearest Neighbors.     : [29, 30, 37, 36, 101, 20, 43, 45, 44, 91, 68, 38, 89, 80, 103, 67, 26, 16, 12, 79]
# --- 0.02 minutes passed ---------
# 31
# 83
# 35
# 88
# 27
# 40
# 65
# 49
# 2
# 46
# 25
# 106
# 0
# 66
# 38
# 97
# 84
# 54
# 73
# 53
# ---------------------------------
# Similarity index       : 31
# Master Image file name : 34_0
# Nearest Neighbors.     : [31, 83, 35, 88, 27, 40, 65, 49, 2, 46, 25, 106, 0, 66, 38, 97, 84, 54, 73, 53]
# --- 0.02 minutes passed ---------
# 32
# 87
# 70
# 108
# 8
# 86
# 82
# 81
# 79
# 76
# 28
# 80
# 109
# 71
# 65
# 9
# 73
# 26
# 22
# 46
# ---------------------------------
# Similarity index       : 32
# Master Image file name : 35_0
# Nearest Neighbors.     : [32, 87, 70, 108, 8, 86, 82, 81, 79, 76, 28, 80, 109, 71, 65, 9, 73, 26, 22, 46]
# --- 0.02 minutes passed ---------
# 33
# 46
# 104
# 39
# 73
# 53
# 82
# 66
# 97
# 40
# 27
# 83
# 22
# 79
# 88
# 54
# 49
# 26
# 2
# 31
# ---------------------------------
# Similarity index       : 33
# Master Image file name : 36_0
# Nearest Neighbors.     : [33, 46, 104, 39, 73, 53, 82, 66, 97, 40, 27, 83, 22, 79, 88, 54, 49, 26, 2, 31]
# --- 0.02 minutes passed ---------
# 34
# 0
# 71
# 98
# 105
# 44
# 106
# 14
# 90
# 15
# 81
# 17
# 25
# 43
# 8
# 13
# 58
# 73
# 55
# 27
# ---------------------------------
# Similarity index       : 34
# Master Image file name : 37_0
# Nearest Neighbors.     : [34, 0, 71, 98, 105, 44, 106, 14, 90, 15, 81, 17, 25, 43, 8, 13, 58, 73, 55, 27]
# --- 0.02 minutes passed ---------
# 35
# 88
# 31
# 83
# 97
# 84
# 106
# 40
# 46
# 53
# 27
# 39
# 104
# 49
# 66
# 50
# 38
# 73
# 2
# 18
# ---------------------------------
# Similarity index       : 35
# Master Image file name : 38_0
# Nearest Neighbors.     : [35, 88, 31, 83, 97, 84, 106, 40, 46, 53, 27, 39, 104, 49, 66, 50, 38, 73, 2, 18]
# --- 0.02 minutes passed ---------
# 36
# 37
# 45
# 29
# 30
# 43
# 68
# 20
# 79
# 44
# 101
# 67
# 91
# 102
# 80
# 89
# 85
# 1
# 103
# 81
# ---------------------------------
# Similarity index       : 36
# Master Image file name : 39_0
# Nearest Neighbors.     : [36, 37, 45, 29, 30, 43, 68, 20, 79, 44, 101, 67, 91, 102, 80, 89, 85, 1, 103, 81]
# --- 0.02 minutes passed ---------
# 37
# 36
# 45
# 29
# 30
# 68
# 20
# 43
# 79
# 101
# 80
# 67
# 102
# 44
# 89
# 81
# 91
# 1
# 85
# 0
# ---------------------------------
# Similarity index       : 37
# Master Image file name : 39_1
# Nearest Neighbors.     : [37, 36, 45, 29, 30, 68, 20, 43, 79, 101, 80, 67, 102, 44, 89, 81, 91, 1, 85, 0]
# --- 0.02 minutes passed ---------
# 38
# 101
# 31
# 25
# 35
# 29
# 30
# 74
# 49
# 106
# 13
# 83
# 77
# 97
# 0
# 89
# 68
# 80
# 63
# 16
# ---------------------------------
# Similarity index       : 38
# Master Image file name : 3_0
# Nearest Neighbors.     : [38, 101, 31, 25, 35, 29, 30, 74, 49, 106, 13, 83, 77, 97, 0, 89, 68, 80, 63, 16]
# --- 0.02 minutes passed ---------
# 39
# 18
# 66
# 40
# 9
# 49
# 33
# 46
# 28
# 13
# 84
# 35
# 17
# 53
# 54
# 22
# 86
# 100
# 19
# 8
# ---------------------------------
# Similarity index       : 39
# Master Image file name : 40_0
# Nearest Neighbors.     : [39, 18, 66, 40, 9, 49, 33, 46, 28, 13, 84, 35, 17, 53, 54, 22, 86, 100, 19, 8]
# --- 0.02 minutes passed ---------
# 40
# 49
# 84
# 88
# 46
# 54
# 2
# 31
# 39
# 28
# 35
# 66
# 53
# 55
# 83
# 73
# 96
# 65
# 27
# 18
# ---------------------------------
# Similarity index       : 40
# Master Image file name : 41_0
# Nearest Neighbors.     : [40, 49, 84, 88, 46, 54, 2, 31, 39, 28, 35, 66, 53, 55, 83, 73, 96, 65, 27, 18]
# --- 0.02 minutes passed ---------
# 41
# 81
# 13
# 8
# 80
# 86
# 39
# 40
# 84
# 71
# 28
# 88
# 69
# 22
# 49
# 35
# 55
# 66
# 89
# 31
# ---------------------------------
# Similarity index       : 41
# Master Image file name : 42_0
# Nearest Neighbors.     : [41, 81, 13, 8, 80, 86, 39, 40, 84, 71, 28, 88, 69, 22, 49, 35, 55, 66, 89, 31]
# --- 0.02 minutes passed ---------
# 42
# 38
# 31
# 19
# 29
# 30
# 22
# 74
# 91
# 40
# 35
# 15
# 12
# 65
# 83
# 0
# 25
# 95
# 46
# 64
# ---------------------------------
# Similarity index       : 42
# Master Image file name : 42_1
# Nearest Neighbors.     : [42, 38, 31, 19, 29, 30, 22, 74, 91, 40, 35, 15, 12, 65, 83, 0, 25, 95, 46, 64]
# --- 0.02 minutes passed ---------
# 43
# 44
# 20
# 101
# 36
# 29
# 30
# 37
# 45
# 16
# 107
# 68
# 103
# 7
# 67
# 85
# 0
# 91
# 81
# 56
# ---------------------------------
# Similarity index       : 43
# Master Image file name : 43_0
# Nearest Neighbors.     : [43, 44, 20, 101, 36, 29, 30, 37, 45, 16, 107, 68, 103, 7, 67, 85, 0, 91, 81, 56]
# --- 0.02 minutes passed ---------
# 44
# 43
# 20
# 101
# 107
# 29
# 30
# 103
# 7
# 36
# 0
# 68
# 67
# 81
# 37
# 16
# 34
# 72
# 79
# 56
# ---------------------------------
# Similarity index       : 44
# Master Image file name : 43_1
# Nearest Neighbors.     : [44, 43, 20, 101, 107, 29, 30, 103, 7, 36, 0, 68, 67, 81, 37, 16, 34, 72, 79, 56]
# --- 0.02 minutes passed ---------
# 45
# 37
# 102
# 36
# 29
# 30
# 16
# 43
# 101
# 68
# 1
# 44
# 91
# 20
# 7
# 74
# 5
# 77
# 38
# 12
# ---------------------------------
# Similarity index       : 45
# Master Image file name : 43_2
# Nearest Neighbors.     : [45, 37, 102, 36, 29, 30, 16, 43, 101, 68, 1, 44, 91, 20, 7, 74, 5, 77, 38, 12]
# --- 0.02 minutes passed ---------
# 46
# 49
# 73
# 33
# 40
# 83
# 26
# 54
# 66
# 18
# 88
# 84
# 39
# 35
# 31
# 22
# 65
# 2
# 69
# 81
# ---------------------------------
# Similarity index       : 46
# Master Image file name : 44_0
# Nearest Neighbors.     : [46, 49, 73, 33, 40, 83, 26, 54, 66, 18, 88, 84, 39, 35, 31, 22, 65, 2, 69, 81]
# --- 0.02 minutes passed ---------
# 47
# 60
# 5
# 59
# 61
# 4
# 7
# 85
# 75
# 103
# 78
# 93
# 62
# 44
# 6
# 43
# 48
# 20
# 0
# 29
# ---------------------------------
# Similarity index       : 47
# Master Image file name : 45_0
# Nearest Neighbors.     : [47, 60, 5, 59, 61, 4, 7, 85, 75, 103, 78, 93, 62, 44, 6, 43, 48, 20, 0, 29]
# --- 0.02 minutes passed ---------
# 48
# 23
# 21
# 74
# 94
# 4
# 5
# 29
# 30
# 38
# 101
# 61
# 91
# 93
# 63
# 35
# 31
# 20
# 7
# 55
# ---------------------------------
# Similarity index       : 48
# Master Image file name : 46_0
# Nearest Neighbors.     : [48, 23, 21, 74, 94, 4, 5, 29, 30, 38, 101, 61, 91, 93, 63, 35, 31, 20, 7, 55]
# --- 0.02 minutes passed ---------
# 49
# 40
# 46
# 28
# 66
# 39
# 31
# 13
# 2
# 73
# 8
# 83
# 88
# 9
# 54
# 18
# 35
# 27
# 96
# 17
# ---------------------------------
# Similarity index       : 49
# Master Image file name : 47_0
# Nearest Neighbors.     : [49, 40, 46, 28, 66, 39, 31, 13, 2, 73, 8, 83, 88, 9, 54, 18, 35, 27, 96, 17]
# --- 0.02 minutes passed ---------
# 50
# 106
# 98
# 105
# 55
# 83
# 0
# 97
# 2
# 15
# 35
# 10
# 27
# 25
# 31
# 84
# 90
# 88
# 71
# 73
# ---------------------------------
# Similarity index       : 50
# Master Image file name : 48_0
# Nearest Neighbors.     : [50, 106, 98, 105, 55, 83, 0, 97, 2, 15, 35, 10, 27, 25, 31, 84, 90, 88, 71, 73]
# --- 0.02 minutes passed ---------
# 51
# 73
# 2
# 40
# 46
# 33
# 83
# 104
# 70
# 66
# 49
# 82
# 53
# 88
# 18
# 35
# 26
# 39
# 65
# 55
# ---------------------------------
# Similarity index       : 51
# Master Image file name : 4_0
# Nearest Neighbors.     : [51, 73, 2, 40, 46, 33, 83, 104, 70, 66, 49, 82, 53, 88, 18, 35, 26, 39, 65, 55]
# --- 0.02 minutes passed ---------
# 52
# 82
# 76
# 3
# 67
# 20
# 81
# 73
# 79
# 66
# 80
# 70
# 78
# 69
# 2
# 89
# 46
# 85
# 55
# 28
# ---------------------------------
# Similarity index       : 52
# Master Image file name : 50_0
# Nearest Neighbors.     : [52, 82, 76, 3, 67, 20, 81, 73, 79, 66, 80, 70, 78, 69, 2, 89, 46, 85, 55, 28]
# --- 0.02 minutes passed ---------
# 53
# 88
# 83
# 54
# 104
# 66
# 73
# 2
# 27
# 40
# 35
# 86
# 33
# 39
# 46
# 97
# 31
# 49
# 18
# 84
# ---------------------------------
# Similarity index       : 53
# Master Image file name : 51_0
# Nearest Neighbors.     : [53, 88, 83, 54, 104, 66, 73, 2, 27, 40, 35, 86, 33, 39, 46, 97, 31, 49, 18, 84]
# --- 0.02 minutes passed ---------
# 54
# 53
# 40
# 18
# 46
# 88
# 86
# 39
# 49
# 66
# 22
# 65
# 31
# 28
# 33
# 9
# 73
# 69
# 83
# 96
# ---------------------------------
# Similarity index       : 54
# Master Image file name : 52_0
# Nearest Neighbors.     : [54, 53, 40, 18, 46, 88, 86, 39, 49, 66, 22, 65, 31, 28, 33, 9, 73, 69, 83, 96]
# --- 0.02 minutes passed ---------
# 55
# 0
# 50
# 40
# 106
# 97
# 71
# 2
# 73
# 83
# 35
# 98
# 49
# 80
# 84
# 81
# 46
# 31
# 88
# 27
# ---------------------------------
# Similarity index       : 55
# Master Image file name : 53_0
# Nearest Neighbors.     : [55, 0, 50, 40, 106, 97, 71, 2, 73, 83, 35, 98, 49, 80, 84, 81, 46, 31, 88, 27]
# --- 0.02 minutes passed ---------
# 56
# 68
# 44
# 35
# 72
# 43
# 46
# 29
# 30
# 97
# 39
# 20
# 81
# 17
# 89
# 79
# 38
# 18
# 66
# 26
# ---------------------------------
# Similarity index       : 56
# Master Image file name : 54_0
# Nearest Neighbors.     : [56, 68, 44, 35, 72, 43, 46, 29, 30, 97, 39, 20, 81, 17, 89, 79, 38, 18, 66, 26]
# --- 0.02 minutes passed ---------
# 57
# 105
# 14
# 106
# 27
# 98
# 58
# 13
# 25
# 8
# 10
# 71
# 0
# 97
# 50
# 90
# 31
# 81
# 2
# 108
# ---------------------------------
# Similarity index       : 57
# Master Image file name : 55_0
# Nearest Neighbors.     : [57, 105, 14, 106, 27, 98, 58, 13, 25, 8, 10, 71, 0, 97, 50, 90, 31, 81, 2, 108]
# --- 0.02 minutes passed ---------
# 58
# 105
# 14
# 0
# 57
# 106
# 25
# 15
# 34
# 27
# 71
# 98
# 17
# 22
# 31
# 90
# 10
# 8
# 95
# 50
# ---------------------------------
# Similarity index       : 58
# Master Image file name : 56_0
# Nearest Neighbors.     : [58, 105, 14, 0, 57, 106, 25, 15, 34, 27, 71, 98, 17, 22, 31, 90, 10, 8, 95, 50]
# --- 0.02 minutes passed ---------
# 59
# 60
# 47
# 61
# 75
# 7
# 4
# 85
# 5
# 6
# 62
# 103
# 78
# 93
# 44
# 81
# 43
# 92
# 20
# 48
# ---------------------------------
# Similarity index       : 59
# Master Image file name : 57_0
# Nearest Neighbors.     : [59, 60, 47, 61, 75, 7, 4, 85, 5, 6, 62, 103, 78, 93, 44, 81, 43, 92, 20, 48]
# --- 0.02 minutes passed ---------
# 60
# 59
# 47
# 61
# 5
# 7
# 85
# 75
# 4
# 62
# 78
# 103
# 6
# 93
# 44
# 20
# 43
# 97
# 81
# 91
# ---------------------------------
# Similarity index       : 60
# Master Image file name : 57_1
# Nearest Neighbors.     : [60, 59, 47, 61, 5, 7, 85, 75, 4, 62, 78, 103, 6, 93, 44, 20, 43, 97, 81, 91]
# --- 0.02 minutes passed ---------
# 61
# 60
# 5
# 47
# 81
# 7
# 4
# 80
# 85
# 59
# 82
# 78
# 103
# 20
# 48
# 26
# 79
# 89
# 97
# 62
# ---------------------------------
# Similarity index       : 61
# Master Image file name : 57_2
# Nearest Neighbors.     : [61, 60, 5, 47, 81, 7, 4, 80, 85, 59, 82, 78, 103, 20, 48, 26, 79, 89, 97, 62]
# --- 0.02 minutes passed ---------
# 62
# 78
# 20
# 97
# 44
# 85
# 81
# 7
# 5
# 61
# 82
# 103
# 73
# 79
# 4
# 89
# 26
# 80
# 75
# 43
# ---------------------------------
# Similarity index       : 62
# Master Image file name : 58_0
# Nearest Neighbors.     : [62, 78, 20, 97, 44, 85, 81, 7, 5, 61, 82, 103, 73, 79, 4, 89, 26, 80, 75, 43]
# --- 0.02 minutes passed ---------
# 63
# 101
# 55
# 77
# 106
# 0
# 38
# 83
# 31
# 25
# 74
# 44
# 88
# 84
# 81
# 50
# 10
# 4
# 35
# 93
# ---------------------------------
# Similarity index       : 63
# Master Image file name : 59_0
# Nearest Neighbors.     : [63, 101, 55, 77, 106, 0, 38, 83, 31, 25, 74, 44, 88, 84, 81, 50, 10, 4, 35, 93]
# --- 0.02 minutes passed ---------
# 64
# 25
# 31
# 0
# 106
# 15
# 92
# 105
# 50
# 63
# 44
# 95
# 101
# 35
# 38
# 55
# 74
# 27
# 97
# 98
# ---------------------------------
# Similarity index       : 64
# Master Image file name : 5_0
# Nearest Neighbors.     : [64, 25, 31, 0, 106, 15, 92, 105, 50, 63, 44, 95, 101, 35, 38, 55, 74, 27, 97, 98]
# --- 0.02 minutes passed ---------
# 65
# 96
# 31
# 88
# 87
# 46
# 40
# 69
# 84
# 83
# 54
# 35
# 73
# 86
# 98
# 27
# 33
# 2
# 28
# 39
# ---------------------------------
# Similarity index       : 65
# Master Image file name : 60_0
# Nearest Neighbors.     : [65, 96, 31, 88, 87, 46, 40, 69, 84, 83, 54, 35, 73, 86, 98, 27, 33, 2, 28, 39]
# --- 0.02 minutes passed ---------
# 66
# 97
# 83
# 2
# 39
# 49
# 46
# 53
# 40
# 27
# 73
# 31
# 106
# 88
# 9
# 81
# 13
# 54
# 33
# 35
# ---------------------------------
# Similarity index       : 66
# Master Image file name : 61_0
# Nearest Neighbors.     : [66, 97, 83, 2, 39, 49, 46, 53, 40, 27, 73, 31, 106, 88, 9, 81, 13, 54, 33, 35]
# --- 0.02 minutes passed ---------
# 67
# 20
# 68
# 79
# 80
# 85
# 29
# 30
# 82
# 81
# 37
# 36
# 44
# 43
# 101
# 89
# 73
# 7
# 26
# 5
# ---------------------------------
# Similarity index       : 67
# Master Image file name : 62_0
# Nearest Neighbors.     : [67, 20, 68, 79, 80, 85, 29, 30, 82, 81, 37, 36, 44, 43, 101, 89, 73, 7, 26, 5]
# --- 0.02 minutes passed ---------
# 68
# 89
# 101
# 80
# 37
# 67
# 20
# 36
# 16
# 29
# 30
# 43
# 44
# 24
# 12
# 56
# 7
# 38
# 81
# 45
# ---------------------------------
# Similarity index       : 68
# Master Image file name : 62_1
# Nearest Neighbors.     : [68, 89, 101, 80, 37, 67, 20, 36, 16, 29, 30, 43, 44, 24, 12, 56, 7, 38, 81, 45]
# --- 0.03 minutes passed ---------
# 69
# 73
# 84
# 46
# 65
# 86
# 79
# 88
# 66
# 40
# 2
# 9
# 28
# 22
# 104
# 39
# 54
# 81
# 27
# 31
# ---------------------------------
# Similarity index       : 69
# Master Image file name : 63_0
# Nearest Neighbors.     : [69, 73, 84, 46, 65, 86, 79, 88, 66, 40, 2, 9, 28, 22, 104, 39, 54, 81, 27, 31]
# --- 0.03 minutes passed ---------
# 70
# 73
# 82
# 9
# 79
# 86
# 46
# 81
# 76
# 2
# 69
# 108
# 51
# 3
# 66
# 26
# 80
# 87
# 71
# 53
# ---------------------------------
# Similarity index       : 70
# Master Image file name : 64_0
# Nearest Neighbors.     : [70, 73, 82, 9, 79, 86, 46, 81, 76, 2, 69, 108, 51, 3, 66, 26, 80, 87, 71, 53]
# --- 0.03 minutes passed ---------
# 71
# 81
# 8
# 90
# 86
# 0
# 80
# 22
# 55
# 13
# 17
# 98
# 105
# 79
# 73
# 34
# 46
# 41
# 14
# 69
# ---------------------------------
# Similarity index       : 71
# Master Image file name : 64_1
# Nearest Neighbors.     : [71, 81, 8, 90, 86, 0, 80, 22, 55, 13, 17, 98, 105, 79, 73, 34, 46, 41, 14, 69]
# --- 0.03 minutes passed ---------
# 72
# 107
# 81
# 44
# 56
# 20
# 79
# 89
# 43
# 105
# 97
# 35
# 80
# 22
# 90
# 103
# 106
# 26
# 71
# 24
# ---------------------------------
# Similarity index       : 72
# Master Image file name : 64_2
# Nearest Neighbors.     : [72, 107, 81, 44, 56, 20, 79, 89, 43, 105, 97, 35, 80, 22, 90, 103, 106, 26, 71, 24]
# --- 0.03 minutes passed ---------
# 73
# 2
# 46
# 27
# 69
# 82
# 79
# 104
# 53
# 0
# 33
# 81
# 49
# 66
# 26
# 70
# 40
# 83
# 105
# 51
# ---------------------------------
# Similarity index       : 73
# Master Image file name : 66_0
# Nearest Neighbors.     : [73, 2, 46, 27, 69, 82, 79, 104, 53, 0, 33, 81, 49, 66, 26, 70, 40, 83, 105, 51]
# --- 0.03 minutes passed ---------
# 74
# 101
# 25
# 94
# 38
# 21
# 16
# 55
# 91
# 48
# 19
# 0
# 29
# 30
# 31
# 23
# 97
# 20
# 63
# 68
# ---------------------------------
# Similarity index       : 74
# Master Image file name : 69_0
# Nearest Neighbors.     : [74, 101, 25, 94, 38, 21, 16, 55, 91, 48, 19, 0, 29, 30, 31, 23, 97, 20, 63, 68]
# --- 0.03 minutes passed ---------
# 75
# 7
# 85
# 5
# 60
# 44
# 43
# 47
# 59
# 4
# 20
# 61
# 103
# 62
# 0
# 93
# 101
# 6
# 81
# 68
# ---------------------------------
# Similarity index       : 75
# Master Image file name : 6_0
# Nearest Neighbors.     : [75, 7, 85, 5, 60, 44, 43, 47, 59, 4, 20, 61, 103, 62, 0, 93, 101, 6, 81, 68]
# --- 0.03 minutes passed ---------
# 76
# 82
# 70
# 73
# 79
# 52
# 11
# 3
# 69
# 108
# 67
# 81
# 78
# 2
# 20
# 51
# 66
# 32
# 71
# 80
# ---------------------------------
# Similarity index       : 76
# Master Image file name : 70_0
# Nearest Neighbors.     : [76, 82, 70, 73, 79, 52, 11, 3, 69, 108, 67, 81, 78, 2, 20, 51, 66, 32, 71, 80]
# --- 0.03 minutes passed ---------
# 77
# 38
# 63
# 101
# 29
# 30
# 74
# 44
# 23
# 68
# 31
# 45
# 43
# 7
# 37
# 48
# 103
# 35
# 88
# 36
# ---------------------------------
# Similarity index       : 77
# Master Image file name : 71_0
# Nearest Neighbors.     : [77, 38, 63, 101, 29, 30, 74, 44, 23, 68, 31, 45, 43, 7, 37, 48, 103, 35, 88, 36]
# --- 0.03 minutes passed ---------
# 78
# 82
# 81
# 97
# 73
# 79
# 85
# 5
# 14
# 105
# 66
# 80
# 104
# 62
# 20
# 106
# 4
# 2
# 26
# 61
# ---------------------------------
# Similarity index       : 78
# Master Image file name : 72_0
# Nearest Neighbors.     : [78, 82, 81, 97, 73, 79, 85, 5, 14, 105, 66, 80, 104, 62, 20, 106, 4, 2, 26, 61]
# --- 0.03 minutes passed ---------
# 79
# 82
# 80
# 81
# 20
# 73
# 89
# 26
# 0
# 97
# 67
# 70
# 11
# 46
# 69
# 33
# 37
# 2
# 71
# 36
# ---------------------------------
# Similarity index       : 79
# Master Image file name : 73_0
# Nearest Neighbors.     : [79, 82, 80, 81, 20, 73, 89, 26, 0, 97, 67, 70, 11, 46, 69, 33, 37, 2, 71, 36]
# --- 0.03 minutes passed ---------
# 80
# 81
# 89
# 79
# 20
# 68
# 82
# 97
# 86
# 26
# 71
# 101
# 41
# 66
# 88
# 83
# 106
# 25
# 22
# 67
# ---------------------------------
# Similarity index       : 80
# Master Image file name : 73_1
# Nearest Neighbors.     : [80, 81, 89, 79, 20, 68, 82, 97, 86, 26, 71, 101, 41, 66, 88, 83, 106, 25, 22, 67]
# --- 0.03 minutes passed ---------
# 81
# 80
# 79
# 26
# 20
# 71
# 89
# 82
# 8
# 73
# 41
# 97
# 13
# 105
# 46
# 66
# 106
# 0
# 78
# 86
# ---------------------------------
# Similarity index       : 81
# Master Image file name : 73_2
# Nearest Neighbors.     : [81, 80, 79, 26, 20, 71, 89, 82, 8, 73, 41, 97, 13, 105, 46, 66, 106, 0, 78, 86]
# --- 0.03 minutes passed ---------
# 82
# 79
# 73
# 78
# 80
# 81
# 70
# 20
# 97
# 33
# 104
# 2
# 76
# 11
# 46
# 66
# 67
# 86
# 69
# 3
# ---------------------------------
# Similarity index       : 82
# Master Image file name : 73_3
# Nearest Neighbors.     : [82, 79, 73, 78, 80, 81, 70, 20, 97, 33, 104, 2, 76, 11, 46, 66, 67, 86, 69, 3]
# --- 0.03 minutes passed ---------
# 83
# 88
# 31
# 27
# 2
# 106
# 35
# 46
# 66
# 53
# 104
# 26
# 40
# 105
# 49
# 50
# 73
# 65
# 0
# 84
# ---------------------------------
# Similarity index       : 83
# Master Image file name : 74_0
# Nearest Neighbors.     : [83, 88, 31, 27, 2, 106, 35, 46, 66, 53, 104, 26, 40, 105, 49, 50, 73, 65, 0, 84]
# --- 0.03 minutes passed ---------
# 84
# 40
# 88
# 35
# 46
# 9
# 69
# 39
# 65
# 96
# 106
# 73
# 83
# 28
# 104
# 66
# 31
# 49
# 27
# 81
# ---------------------------------
# Similarity index       : 84
# Master Image file name : 75_0
# Nearest Neighbors.     : [84, 40, 88, 35, 46, 9, 69, 39, 65, 96, 106, 73, 83, 28, 104, 66, 31, 49, 27, 81]
# --- 0.03 minutes passed ---------
# 85
# 7
# 20
# 5
# 67
# 4
# 78
# 97
# 81
# 47
# 44
# 75
# 43
# 61
# 103
# 79
# 36
# 37
# 60
# 29
# ---------------------------------
# Similarity index       : 85
# Master Image file name : 76_0
# Nearest Neighbors.     : [85, 7, 20, 5, 67, 4, 78, 97, 81, 47, 44, 75, 43, 61, 103, 79, 36, 37, 60, 29]
# --- 0.03 minutes passed ---------
# 86
# 22
# 88
# 71
# 80
# 53
# 54
# 69
# 81
# 39
# 8
# 73
# 83
# 41
# 46
# 109
# 70
# 65
# 84
# 79
# ---------------------------------
# Similarity index       : 86
# Master Image file name : 76_1
# Nearest Neighbors.     : [86, 22, 88, 71, 80, 53, 54, 69, 81, 39, 8, 73, 83, 41, 46, 109, 70, 65, 84, 79]
# --- 0.03 minutes passed ---------
# 87
# 9
# 65
# 96
# 28
# 84
# 40
# 46
# 69
# 86
# 54
# 90
# 73
# 31
# 70
# 66
# 49
# 71
# 109
# 35
# ---------------------------------
# Similarity index       : 87
# Master Image file name : 77_0
# Nearest Neighbors.     : [87, 9, 65, 96, 28, 84, 40, 46, 69, 86, 54, 90, 73, 31, 70, 66, 49, 71, 109, 35]
# --- 0.03 minutes passed ---------
# 88
# 83
# 35
# 31
# 53
# 40
# 84
# 2
# 86
# 46
# 65
# 54
# 104
# 49
# 66
# 18
# 27
# 106
# 80
# 69
# ---------------------------------
# Similarity index       : 88
# Master Image file name : 79_0
# Nearest Neighbors.     : [88, 83, 35, 31, 53, 40, 84, 2, 86, 46, 65, 54, 104, 49, 66, 18, 27, 106, 80, 69]
# --- 0.03 minutes passed ---------
# 89
# 80
# 68
# 81
# 79
# 20
# 97
# 26
# 13
# 29
# 30
# 66
# 25
# 101
# 106
# 82
# 38
# 39
# 49
# 37
# ---------------------------------
# Similarity index       : 89
# Master Image file name : 7_0
# Nearest Neighbors.     : [89, 80, 68, 81, 79, 20, 97, 26, 13, 29, 30, 66, 25, 101, 106, 82, 38, 39, 49, 37]
# --- 0.03 minutes passed ---------
# 90
# 71
# 46
# 73
# 0
# 50
# 17
# 105
# 22
# 81
# 98
# 95
# 8
# 84
# 69
# 49
# 34
# 87
# 28
# 13
# ---------------------------------
# Similarity index       : 90
# Master Image file name : 80_0
# Nearest Neighbors.     : [90, 71, 46, 73, 0, 50, 17, 105, 22, 81, 98, 95, 8, 84, 69, 49, 34, 87, 28, 13]
# --- 0.03 minutes passed ---------
# 91
# 101
# 29
# 30
# 20
# 74
# 36
# 44
# 43
# 37
# 0
# 26
# 103
# 12
# 45
# 68
# 48
# 5
# 81
# 16
# ---------------------------------
# Similarity index       : 91
# Master Image file name : 81_0
# Nearest Neighbors.     : [91, 101, 29, 30, 20, 74, 36, 44, 43, 37, 0, 26, 103, 12, 45, 68, 48, 5, 81, 16]
# --- 0.03 minutes passed ---------
# 92
# 50
# 106
# 15
# 31
# 0
# 25
# 98
# 97
# 65
# 95
# 35
# 105
# 27
# 55
# 44
# 64
# 63
# 103
# 14
# ---------------------------------
# Similarity index       : 92
# Master Image file name : 83_0
# Nearest Neighbors.     : [92, 50, 106, 15, 31, 0, 25, 98, 97, 65, 95, 35, 105, 27, 55, 44, 64, 63, 103, 14]
# --- 0.03 minutes passed ---------
# 93
# 4
# 85
# 29
# 30
# 48
# 63
# 7
# 101
# 103
# 31
# 91
# 23
# 75
# 47
# 74
# 20
# 77
# 83
# 35
# ---------------------------------
# Similarity index       : 93
# Master Image file name : 84_0
# Nearest Neighbors.     : [93, 4, 85, 29, 30, 48, 63, 7, 101, 103, 31, 91, 23, 75, 47, 74, 20, 77, 83, 35]
# --- 0.03 minutes passed ---------
# 94
# 21
# 23
# 74
# 48
# 29
# 30
# 16
# 101
# 25
# 38
# 19
# 4
# 45
# 68
# 12
# 91
# 77
# 63
# 93
# ---------------------------------
# Similarity index       : 94
# Master Image file name : 87_0
# Nearest Neighbors.     : [94, 21, 23, 74, 48, 29, 30, 16, 101, 25, 38, 19, 4, 45, 68, 12, 91, 77, 63, 93]
# --- 0.03 minutes passed ---------
# 95
# 15
# 90
# 0
# 98
# 92
# 31
# 105
# 50
# 65
# 96
# 73
# 46
# 87
# 25
# 17
# 55
# 35
# 106
# 71
# ---------------------------------
# Similarity index       : 95
# Master Image file name : 88_0
# Nearest Neighbors.     : [95, 15, 90, 0, 98, 92, 31, 105, 50, 65, 96, 73, 46, 87, 25, 17, 55, 35, 106, 71]
# --- 0.03 minutes passed ---------
# 96
# 65
# 28
# 40
# 84
# 87
# 49
# 9
# 31
# 54
# 39
# 46
# 66
# 97
# 88
# 83
# 35
# 18
# 106
# 33
# ---------------------------------
# Similarity index       : 96
# Master Image file name : 89_0
# Nearest Neighbors.     : [96, 65, 28, 40, 84, 87, 49, 9, 31, 54, 39, 46, 66, 97, 88, 83, 35, 18, 106, 33]
# --- 0.03 minutes passed ---------
# 97
# 106
# 66
# 35
# 105
# 27
# 25
# 80
# 20
# 81
# 0
# 55
# 89
# 79
# 82
# 2
# 104
# 73
# 50
# 33
# ---------------------------------
# Similarity index       : 97
# Master Image file name : 8_0
# Nearest Neighbors.     : [97, 106, 66, 35, 105, 27, 25, 80, 20, 81, 0, 55, 89, 79, 82, 2, 104, 73, 50, 33]
# --- 0.03 minutes passed ---------
# 98
# 50
# 15
# 105
# 106
# 10
# 0
# 71
# 25
# 55
# 57
# 31
# 108
# 65
# 27
# 2
# 34
# 90
# 40
# 14
# ---------------------------------
# Similarity index       : 98
# Master Image file name : 90_0
# Nearest Neighbors.     : [98, 50, 15, 105, 106, 10, 0, 71, 25, 55, 57, 31, 108, 65, 27, 2, 34, 90, 40, 14]
# --- 0.03 minutes passed ---------
# 99
# 31
# 88
# 35
# 38
# 84
# 41
# 63
# 65
# 40
# 96
# 98
# 28
# 83
# 25
# 18
# 86
# 80
# 93
# 106
# ---------------------------------
# Similarity index       : 99
# Master Image file name : 91_0
# Nearest Neighbors.     : [99, 31, 88, 35, 38, 84, 41, 63, 65, 40, 96, 98, 28, 83, 25, 18, 86, 80, 93, 106]
# --- 0.03 minutes passed ---------
# 100
# 39
# 8
# 27
# 13
# 53
# 40
# 46
# 66
# 55
# 33
# 19
# 84
# 81
# 97
# 31
# 54
# 106
# 73
# 83
# ---------------------------------
# Similarity index       : 100
# Master Image file name : 92_0
# Nearest Neighbors.     : [100, 39, 8, 27, 13, 53, 40, 46, 66, 55, 33, 19, 84, 81, 97, 31, 54, 106, 73, 83]
# --- 0.03 minutes passed ---------
# 101
# 16
# 20
# 68
# 29
# 30
# 44
# 74
# 43
# 63
# 38
# 0
# 80
# 91
# 37
# 45
# 36
# 25
# 89
# 81
# ---------------------------------
# Similarity index       : 101
# Master Image file name : 95_0
# Nearest Neighbors.     : [101, 16, 20, 68, 29, 30, 44, 74, 43, 63, 38, 0, 80, 91, 37, 45, 36, 25, 89, 81]
# --- 0.03 minutes passed ---------
# 102
# 45
# 1
# 37
# 36
# 29
# 30
# 43
# 103
# 91
# 6
# 44
# 77
# 68
# 7
# 5
# 101
# 79
# 16
# 74
# ---------------------------------
# Similarity index       : 102
# Master Image file name : 97_0
# Nearest Neighbors.     : [102, 45, 1, 37, 36, 29, 30, 43, 103, 91, 6, 44, 77, 68, 7, 5, 101, 79, 16, 74]
# --- 0.03 minutes passed ---------
# 103
# 44
# 29
# 30
# 43
# 20
# 107
# 7
# 85
# 81
# 67
# 36
# 91
# 35
# 5
# 4
# 97
# 61
# 79
# 37
# ---------------------------------
# Similarity index       : 103
# Master Image file name : 97_1
# Nearest Neighbors.     : [103, 44, 29, 30, 43, 20, 107, 7, 85, 81, 67, 36, 91, 35, 5, 4, 97, 61, 79, 37]
# --- 0.03 minutes passed ---------
# 104
# 33
# 73
# 53
# 2
# 83
# 88
# 105
# 35
# 27
# 97
# 106
# 66
# 82
# 84
# 39
# 69
# 40
# 46
# 49
# ---------------------------------
# Similarity index       : 104
# Master Image file name : 98_0
# Nearest Neighbors.     : [104, 33, 73, 53, 2, 83, 88, 105, 35, 27, 97, 106, 66, 82, 84, 39, 69, 40, 46, 49]
# --- 0.03 minutes passed ---------
# 105
# 106
# 27
# 0
# 14
# 97
# 57
# 50
# 25
# 98
# 13
# 2
# 83
# 104
# 81
# 73
# 10
# 84
# 31
# 8
# ---------------------------------
# Similarity index       : 105
# Master Image file name : 98_1
# Nearest Neighbors.     : [105, 106, 27, 0, 14, 97, 57, 50, 25, 98, 13, 2, 83, 104, 81, 73, 10, 84, 31, 8]
# --- 0.03 minutes passed ---------
# 106
# 105
# 27
# 97
# 0
# 25
# 83
# 50
# 14
# 35
# 2
# 31
# 55
# 66
# 98
# 81
# 57
# 84
# 104
# 13
# ---------------------------------
# Similarity index       : 106
# Master Image file name : 98_2
# Nearest Neighbors.     : [106, 105, 27, 97, 0, 25, 83, 50, 14, 35, 2, 31, 55, 66, 98, 81, 57, 84, 104, 13]
# --- 0.03 minutes passed ---------
# 107
# 44
# 72
# 43
# 103
# 20
# 89
# 97
# 106
# 105
# 36
# 29
# 30
# 56
# 79
# 1
# 37
# 25
# 35
# 24
# ---------------------------------
# Similarity index       : 107
# Master Image file name : 98_3
# Nearest Neighbors.     : [107, 44, 72, 43, 103, 20, 89, 97, 106, 105, 36, 29, 30, 56, 79, 1, 37, 25, 35, 24]
# --- 0.03 minutes passed ---------
# 108
# 73
# 0
# 98
# 105
# 2
# 10
# 14
# 70
# 71
# 81
# 55
# 82
# 79
# 86
# 50
# 8
# 106
# 28
# 97
# ---------------------------------
# Similarity index       : 108
# Master Image file name : 99_0
# Nearest Neighbors.     : [108, 73, 0, 98, 105, 2, 10, 14, 70, 71, 81, 55, 82, 79, 86, 50, 8, 106, 28, 97]
# --- 0.03 minutes passed ---------
# 109
# 86
# 54
# 53
# 87
# 88
# 96
# 22
# 65
# 40
# 104
# 28
# 73
# 84
# 69
# 9
# 32
# 2
# 31
# 41
# ---------------------------------
# Similarity index       : 109
# Master Image file name : 9_0
# Nearest Neighbors.     : [109, 86, 54, 53, 87, 88, 96, 22, 65, 40, 104, 28, 73, 84, 69, 9, 32, 2, 31, 41]
# --- 0.03 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.03 minutes ---------
